# %% [markdown]
# # Tumor Map Clustering

# %% [markdown]
# ### Data Preprocessing
# Ask user for the file name to extract the data

# %%
import pandas as pd

file_name = input("Enter file name: ")
df = pd.read_csv(file_name, delimiter="\t")

# %% [markdown]
# ##### Sanity check
# Observe the data by viewing **head**, **shape** and **column names**

# %%
df.head

# %%
df.shape #(269,9) 269 samples, 9 columns 
print(df.columns) #['th_dataset_id', 'disease', 'age_at_dx', 'pedaya', 'sex', 'study_donor_id', 'study_dataset_id', 'study_id', 'organism']

# %% [markdown]
# #### Extract unique values in columns

# %%
for col in df.columns:
    print(f"Unique values in column '{col}' : ")
    print(df[col].unique(), "\n")

# %% [markdown]
# ```
# Unique values in column 'th_dataset_id':
# ['THR14_1180_S01' 'THR14_1181_S01' 'THR14_1182_S01' 'THR14_1183_S01'
#  'THR14_1184_S01' 'THR14_1185_S01' 'THR14_1186_S01' 'THR14_1188_S01'
#  'THR14_1189_S01' 'TH01_0119_S01' 'THR14_1190_S01' 'THR14_1191_S01'
#  'THR14_1192_S01' 'THR14_1193_S01' 'THR14_1194_S01' 'THR14_1195_S01'
#  'THR14_1196_S01' 'THR14_1197_S01' 'THR14_1198_S01' 'THR14_1199_S01'
#  'THR14_1199_S02' 'TH01_0120_S01' 'THR14_1200_S01' 'THR14_1201_S01'
#  'THR14_1202_S01' 'THR14_1203_S01' 'THR14_1204_S01' 'THR14_1206_S01'
#  'THR14_1208_S01' 'THR14_1209_S01' 'TH01_0121_S01' 'THR14_1210_S01'
#  'THR14_1211_S01' 'THR14_1212_S01' 'THR14_1213_S01' 'THR14_1214_S01'
#  'THR14_1215_S01' 'THR14_1216_S01' 'THR14_1217_S01' 'THR14_1218_S01'
#  'THR14_1219_S01' 'TH01_0122_S01' 'THR14_1220_S01' 'THR14_1221_S01'
#  'THR14_1222_S01' 'THR14_1223_S01' 'THR14_1229_S01' 'TH01_0123_S01'
#  'THR14_1231_S01' 'THR14_1232_S01' 'THR14_1233_S01' 'THR14_1234_S01'
#  'THR14_1235_S01' 'THR14_1236_S01' 'THR14_1236_S02' 'THR14_1237_S01'
#  'TH01_0124_S01' 'TH01_0125_S01' 'TH01_0126_S01' 'TH01_0127_S01'
#  'TH01_0128_S01' 'TH01_0129_S01' 'TH01_0130_S01' 'TH38_1309_S01'
#  'TH01_0131_S01' 'TH38_1310_S01' 'TH38_1313_S01' 'TH38_1315_S01'
#  'TH38_1316_S01' 'TH38_1317_S01' 'TH38_1318_S01' 'TH38_1319_S01'
#  'TH01_0132_S01' 'TH38_1320_S01' 'TH38_1321_S01' 'TH38_1322_S01'
#  'TH38_1323_S01' 'TH38_1324_S01' 'TH38_1325_S01' 'TH38_1326_S01'
#  'TH38_1327_S01' 'TH38_1328_S01' 'TH38_1329_S01' 'TH01_0133_S01'
#  'TH38_1330_S01' 'TH38_1331_S01' 'TH38_1333_S01' 'TH38_1334_S01'
#  'TH38_1335_S01' 'TH38_1335_S02' 'TH38_1337_S01' 'TH38_1338_S02'
#  'TH38_1338_S03' 'TH38_1339_S01' 'TH01_0134_S01' 'TH38_1340_S02'
#  'TH38_1341_S01' 'TH38_1341_S02' 'TH38_1342_S01' 'TH38_1344_S02'
#  'TH38_1345_S01' 'TH01_0135_S01' 'TH38_1416_S01' 'TH38_1417_S01'
#  'TH38_1418_S01' 'TH38_1420_S01' 'TH38_1421_S01' 'TH38_1422_S01'
#  'TH38_1423_S01' 'TH38_1424_S01' 'TH38_1425_S01' 'TH38_1426_S01'
#  'TH38_1427_S01' 'TH38_1427_S02' 'TH38_1428_S01' 'TH38_1429_S01'
#  'TH38_1430_S01' 'TH38_1431_S01' 'TH38_1432_S01' 'TH38_1433_S01'
#  'TH38_1434_S01' 'TH38_1435_S01' 'TH38_1435_S02' 'TH38_1436_S01'
#  'TH38_1437_S01' 'TH38_1437_S02' 'TH38_1438_S01' 'TH38_1439_S01'
#  'TH38_1440_S01' 'TH38_1441_S01' 'TH38_1442_S01' 'TH38_1442_S02'
#  'TH38_1443_S01' 'THR12_0277_S01' 'THR12_0278_S01' 'THR12_0278_S03'
#  'THR12_0279_S01' 'THR12_0280_S01' 'THR12_0280_S03' 'THR12_0280_S04'
#  'THR12_0281_S01' 'THR12_0282_S01' 'THR14_0310_S02' 'THR12_0365_S01'
#  'THR12_0365_S02' 'THR12_0365_S03' 'THR12_0365_S04' 'THR12_0365_S06'
#  'THR12_0366_S02' 'THR12_0366_S03' 'THR12_0366_S04' 'THR12_0368_S01'
#  'THR12_0369_S01' 'THR12_0370_S01' 'THR19_0410_S01' 'THR19_0411_S01'
#  'THR19_0412_S01' 'THR19_0413_S01' 'THR19_0414_S01' 'THR19_0415_S01'
#  'THR19_0416_S01' 'THR19_0417_S01' 'THR19_0418_S01' 'THR19_0419_S01'
#  'THR19_0420_S01' 'THR19_0421_S01' 'THR19_0422_S01' 'THR19_0423_S01'
#  'THR19_0424_S01' 'THR19_0425_S01' 'THR19_0426_S01' 'THR19_0427_S01'
#  'THR19_0428_S01' 'THR19_0429_S01' 'THR19_0430_S01' 'THR19_0431_S01'
#  'THR19_0432_S01' 'THR19_0433_S01' 'THR19_0434_S01' 'THR19_0435_S01'
#  'THR19_0436_S01' 'THR19_0437_S01' 'THR19_0438_S01' 'THR19_0439_S01'
#  'THR19_0448_S01' 'THR19_0464_S01' 'THR19_0465_S01' 'THR19_0468_S01'
#  'THR19_0469_S01' 'THR19_0470_S01' 'THR19_0471_S01' 'THR19_0472_S01'
#  'THR19_0473_S01' 'THR19_0474_S01' 'THR19_0475_S01' 'THR19_0476_S01'
#  'THR19_0477_S01' 'THR19_0478_S01' 'THR19_0479_S01' 'THR19_0480_S01'
#  'THR21_0520_S01' 'THR21_0521_S01' 'THR21_0522_S01' 'THR21_0523_S01'
#  'THR21_0524_S01' 'THR21_0525_S01' 'THR21_0526_S01' 'THR21_0527_S01'
#  'THR21_0528_S01' 'THR21_0530_S01' 'THR21_0531_S01' 'THR21_0532_S01'
#  'THR21_0532_S02' 'THR21_0532_S03' 'THR21_0533_S01' 'THR21_0534_S01'
#  'THR21_0537_S01' 'THR21_0538_S01' 'THR21_0539_S01' 'THR21_0540_S01'
#  'THR21_0541_S01' 'THR21_0542_S01' 'THR21_0543_S01' 'THR21_0544_S01'
#  'THR21_0545_S01' 'THR21_0546_S01' 'THR21_0547_S01' 'THR21_0548_S01'
#  'THR21_0549_S01' 'THR21_0550_S01' 'THR21_0551_S01' 'THR21_0552_S01'
#  'THR21_0553_S01' 'THR21_0554_S01' 'THR21_0554_S02' 'THR21_0555_S01'
#  'THR21_0556_S01' 'THR21_0557_S01' 'THR21_0558_S01' 'THR21_0559_S01'
#  'THR21_0560_S01' 'TH01_0658_S01' 'TH01_0659_S01' 'TH01_0661_S01'
#  'TH01_0662_S01' 'TH01_0663_S01' 'TH01_0664_S01' 'TH01_0665_S01'
#  'TH01_0666_S01' 'TH01_0666_S02' 'TH01_0666_S03' 'TH01_0667_S01'
#  'TH01_0667_S02' 'TH01_0668_S01' 'TH01_0669_S01' 'TH01_0670_S01'
#  'TH01_0671_S01' 'TH01_0672_S01' 'TH01_0673_S01' 'TH01_0674_S01'
#  'TH01_0675_S01' 'TH01_0676_S01' 'TH01_0676_S02' 'TH01_0677_S01'
#  'TH01_0678_S01' 'TH01_0679_S01' 'TH01_0679_S02' 'TH01_0680_S01'
#  'TH01_0681_S01' 'TH01_0681_S02' 'TH01_0706_S01' 'TH01_0707_S01'
#  'TH01_0708_S01' 'TH01_0709_S01' 'TH01_0709_S02' 'TH01_0710_S01'
#  'TH01_0711_S01' 'TH01_0712_S01' 'TH01_0713_S01' 'TH01_0714_S01'
#  'TH01_0715_S01' 'TH01_0716_S01' 'TH01_0718_S01' 'TARGET-51-PAEALX-01'
#  'TARGET-51-PAJLIV-01' 'TARGET-51-PAJLWU-01' 'TARGET-51-PAJMFS-01'
#  'TARGET-51-PAJMNM-01' 'TARGET-51-PAJNCV-01' 'TARGET-51-PAJPFB-01'
#  'TARGET-51-PAKWMM-01' 'TARGET-51-PALEIR-01' 'TARGET-51-PALFEF-01'
#  'TARGET-51-PALFYG-01' 'TARGET-51-PALKEI-01' 'TARGET-51-PALLXV-01']
# ```
#
# ```
# Unique values in column 'disease':
# ['glioma' 'medulloblastoma' 'ependymoma'
#  'primitive neuroectodermal tumor of the central nervous system'
#  'leukemia/lymphoma' nan 'acute myeloid leukemia' 'gliomatosis cerebri'
#  'acute lymphoblastic leukemia' 'dysembryoplastic neuroepithelial tumor'
#  'alveolar rhabdomyosarcoma' 'neuroblastoma' 'glioblastoma multiforme'
#  'Ewing sarcoma' 'chordoma' 'atypical teratoid/rhabdoid tumor'
#  'glioma, diffuse glioma' 'choroid plexus carcinoma' 'lymphoma'
#  'osteosarcoma' 'myofibroblastoma' 'sarcoma' 'pineoblastoma' 'wilms tumor'
#  'myofibromatosis' 'clear cell adenocarcinoma NOS' 'pituitary adenoma'
#  'neuroendocrine carcinoma' 'fibrolamellar hepatocellular carcinoma'
#  'astrocytoma' 'diffuse large B-cell lymphoma' 'rhabdomyosarcoma'
#  'essential thrombocythemia' 'Langerhans cell histiocytosis'
#  'synovial sarcoma' 'oligodendroglioma'
#  'neuroblastoma with solid-papillary neoplasm of the pancreas'
#  'gastrointestinal stromal tumor'
#  'recurrence of metastatic medulloblastoma'
#  'clear cell sarcoma of the kidney' 'clear cell carcinoma of the kidney']
#
# ```
#
# ```
# Unique values in column 'age_at_dx':
# [20.1  10.2  11.6   5.7  11.5   1.3  17.2   7.9   8.3  13.    8.2  12.4
#  18.4  15.1  19.4  12.2  14.9   5.2  12.   14.   18.5  12.3   4.1  14.1
#  14.5  18.3   7.3  10.    3.5   2.1  16.7  15.3  11.7   9.   10.7   6.5
#   4.    5.    9.6  13.8   3.8   3.4  15.2  15.4   4.7   6.    0.58  8.
#   6.2   7.   15.   17.    0.5   3.    1.75  2.   16.   24.   21.   22.
#   1.33  1.66   nan  0.83 11.    0.06  1.   50.   40.   29.   27.   25.
#  19.   18.   28.    8.4   4.8   0.65  1.56  2.6   3.05  1.38  0.69  1.26
#   1.63  0.7   2.86  1.27]
#
# ```
# ```
#
# Unique values in column 'pedaya':
# ['Yes, age < 30 years' 'Unknown' nan]
#
# ```
# ```
# Unique values in column 'sex':
# ['male' 'female' 'unknown' nan]
# ```
# ```
# Unique values in column 'study_donor_id':
# ['C466170' 'C67527' 'C58548' 'C114267' 'C21771' 'C114513' 'C385482'
#  'C105903' 'C657435' nan 'C122508' 'C30381' 'C20172' 'C70356' 'C54858'
#  'C312912' 'C292125' 'C334314' 'C15498' 'C97416' 'C291756' 'C124353'
#  'C271092' 'C135792' 'C103935' 'C60393' 'C16359' 'C139851' 'C300981'
#  'C132717' 'C475764' 'C413034' 'C173676' 'C170601' 'C169125' 'C132594'
#  'C131118' 'C138990' 'C291879' 'C34440' 'C46494' 'C132963' 'C19803'
#  'C21402' 'C28905' 'C52890' 'C39729' 'C25830' 'C56211' 'C42435'
#  'Subject_101' 'Subject_102' 'Subject_105' 'Subject_110' 'Subject_111'
#  'Subject_113' 'C88806' 'Subject_103' 'Subject_104' 'Subject_107'
#  'Subject_108' 'Subject_109'
#  'icgc/_EGAR00001124498_RNA-seq_PAIRED_ICGC_PA100_s_120626_2b'
#  'icgc/_EGAR00001124499_RNA-seq_PAIRED_ICGC_PA102_s_120626_5a'
#  'icgc/_EGAR00001124500_RNA-seq_PAIRED_ICGC_PA103_s_120626_3a'
#  'icgc/_EGAR00001124501_RNA-seq_PAIRED_ICGC_PA105_s_120626_7c'
#  'icgc/_EGAR00001124502_RNA-seq_PAIRED_ICGC_PA107_s_120705_3b'
#  'icgc/_EGAR00001124503_RNA-seq_PAIRED_ICGC_PA108_s_120705_4c'
#  'icgc/_EGAR00001124504_RNA-seq_PAIRED_ICGC_PA109_s_120705_5c'
#  'icgc/_EGAR00001124505_RNA-seq_PAIRED_ICGC_PA110_s_120705_6a'
#  'icgc/_EGAR00001124506_RNA-seq_PAIRED_ICGC_PA112_s_120705_7b'
#  'icgc/_EGAR00001124507_RNA-seq_PAIRED_ICGC_PA116_s_120705_5a'
#  'icgc/_EGAR00001124508_RNA-seq_PAIRED_ICGC_PA117_s_120705_4b'
#  'icgc/_EGAR00001124509_RNA-seq_PAIRED_ICGC_PA11_s_120816_5a'
#  'icgc/_EGAR00001124510_RNA-seq_PAIRED_ICGC_PA134_s_120816_2b'
#  'icgc/_EGAR00001124511_RNA-seq_PAIRED_ICGC_PA135_s_120816_2a'
#  'icgc/_EGAR00001124512_RNA-seq_PAIRED_ICGC_PA136_s_120816_2c'
#  'icgc/_EGAR00001124513_RNA-seq_PAIRED_ICGC_PA138_s_120816_3b'
#  'icgc/_EGAR00001124514_RNA-seq_PAIRED_ICGC_PA140_s_120816_1b'
#  'icgc/_EGAR00001124516_RNA-seq_PAIRED_ICGC_PA143_s_120816_4c'
#  'icgc/_EGAR00001124517_RNA-seq_PAIRED_ICGC_PA144_s_120925_1b'
#  'icgc/_EGAR00001124518_RNA-seq_PAIRED_ICGC_PA145_s_120816_4a'
#  'icgc/_EGAR00001124519_RNA-seq_PAIRED_ICGC_PA147_s_120816_5b'
#  'icgc/_EGAR00001124520_RNA-seq_PAIRED_ICGC_PA148_s_120925_2b'
#  'icgc/_EGAR00001124521_RNA-seq_PAIRED_ICGC_PA14_s_120816_5c'
#  'icgc/_EGAR00001124522_RNA-seq_PAIRED_ICGC_PA150_s_120816_8a'
#  'icgc/_EGAR00001124523_RNA-seq_PAIRED_ICGC_PA157_s_120925_1a'
#  'icgc/_EGAR00001124524_RNA-seq_PAIRED_ICGC_PA158_s_120816_8c'
#  'icgc/_EGAR00001124525_RNA-seq_PAIRED_ICGC_PA159_s_120816_3a'
#  'icgc/_EGAR00001124526_RNA-seq_PAIRED_ICGC_PA162_s_120816_1c'
#  'icgc/_EGAR00001124527_RNA-seq_PAIRED_ICGC_PA163_s_120925_2a'
#  'icgc/_EGAR00001124528_RNA-seq_PAIRED_ICGC_PA165_s_120816_4b'
#  'icgc/_EGAR00001124537_RNA-seq_PAIRED_ICGC_PA4_s_120816_4c'
#  'icgc/_EGAR00001124553_RNA-seq_PAIRED_ICGC_PA82_s_120626_4b'
#  'icgc/_EGAR00001124554_RNA-seq_PAIRED_ICGC_PA83_s_120626_1a'
#  'icgc/_EGAR00001124561_RNA-seq_PAIRED_ICGC_PA88_s_120626_2c'
#  'icgc/_EGAR00001124562_RNA-seq_PAIRED_ICGC_PA89_s_120626_4c'
#  'icgc/_EGAR00001124563_RNA-seq_PAIRED_ICGC_PA8_s_120816_4b'
#  'icgc/_EGAR00001124564_RNA-seq_PAIRED_ICGC_PA91_s_120626_3b'
#  'icgc/_EGAR00001124565_RNA-seq_PAIRED_ICGC_PA92_s_120626_7a'
#  'icgc/_EGAR00001124566_RNA-seq_PAIRED_ICGC_PA93_s_120626_6a'
#  'icgc/_EGAR00001124567_RNA-seq_PAIRED_ICGC_PA94_s_120626_4a'
#  'icgc/_EGAR00001124570_RNA-seq_PAIRED_ICGC_PA96_s_120626_5c'
#  'icgc/_EGAR00001124573_RNA-seq_PAIRED_ICGC_PA99_s_120626_6c'
#  'icgc/_EGAR00001124574_RNA-seq_PAIRED_ICGC_PA9_s_120816_5b'
#  'icgc/EGAD00001000617_ICGC_PA84_RNA-seq'
#  'icgc/EGAD00001000617_ICGC_PA87_RNA-seq'
#  'icgc/EGAD00001000617_ICGC_PA95_RNA-seq'
#  'icgc/_EGAR00001415737_RNA_PAIRED_ICGC_GBM15_tumor_SN935_0182_B_C2UKHACXXs_131105_1'
#  'icgc/_EGAR00001415749_RNA_PAIRED_ICGC_GBM24_tumor_SN935_0169_B_D2335ACXXs_130809_5'
#  'icgc/_EGAR00001415750_RNA_PAIRED_ICGC_GBM25_tumor_SN935_0169_B_D2335ACXXs_130809_6'
#  'icgc/_EGAR00001415751_RNA_PAIRED_ICGC_GBM26_tumor_SN935_0169_B_D2335ACXXs_130809_7'
#  'icgc/_EGAR00001415752_RNA_PAIRED_ICGC_GBM27_tumor_SN935_0182_B_C2UKHACXXs_131105_2'
#  'icgc/_EGAR00001415753_RNA_PAIRED_ICGC_GBM28_tumor_SN935_0182_B_C2UKHACXXs_131105_3'
#  'icgc/_EGAR00001415754_RNA_PAIRED_ICGC_GBM32_tumor_SN935_0182_B_C2UKHACXXs_131105_5'
#  'icgc/_EGAR00001415755_RNA_PAIRED_ICGC_GBM33_tumor_SN935_0182_B_C2UKHACXXs_131105_6'
#  'icgc/_EGAR00001415756_RNA_PAIRED_ICGC_GBM34_tumor_SN935_0182_B_C2UKHACXXs_131105_7'
#  'icgc/_EGAR00001415758_RNA_PAIRED_ICGC_GBM38_tumor_SN546_0224_B_C2U5JACXXs_131127_1'
#  'icgc/_EGAR00001415759_RNA_PAIRED_ICGC_GBM39_tumor_SN546_0224_B_C2U5JACXXs_131127_2'
#  'icgc/_EGAR00001415760_RNA_PAIRED_ICGC_GBM4_tumor_SN546_0221_B_C2TB7ACXXs_131022_8'
#  'icgc/_EGAR00001415761_RNA_PAIRED_ICGC_GBM40_tumor_SN546_0224_B_C2U5JACXXs_131127_4'
#  'icgc/_EGAR00001415762_RNA_PAIRED_ICGC_GBM41_tumor_SN546_0224_B_C2U5JACXXs_131127_3'
#  'icgc/_EGAR00001415767_RNA_PAIRED_ICGC_GBM52_tumor_SN546_0234_A_C3G07ACXXs_140411_3'
#  'icgc/_EGAR00001415768_RNA_PAIRED_ICGC_GBM53_tumor_SN546_0234_A_C3G07ACXXs_140411_4'
#  'icgc/_EGAR00001415769_RNA_PAIRED_ICGC_GBM56_tumor_SN546_0255_A_C5R5YACXXs_141028_7'
#  'icgc/_EGAR00001415770_RNA_PAIRED_ICGC_GBM57_tumor_SN546_0234_A_C3G07ACXXs_140411_6'
#  'icgc/_EGAR00001415771_RNA_PAIRED_ICGC_GBM58_tumor_SN546_0234_A_C3G07ACXXs_140411_7'
#  'icgc/_EGAR00001415772_RNA_PAIRED_ICGC_GBM59_tumor_SN546_0234_A_C3G07ACXXs_140411_8'
#  'icgc/_EGAR00001415775_RNA_PAIRED_ICGC_GBM60_tumor_SN546_0235_B_C3NW7ACXXs_140411_1'
#  'icgc/_EGAR00001415776_RNA_PAIRED_ICGC_GBM62_tumor_SN935_0203_B_C48T1ACXXs_140821_1'
#  'icgc/_EGAR00001415777_RNA_PAIRED_ICGC_GBM63_tumor_SN546_0255_A_C5R5YACXXs_141028_8'
#  'icgc/_EGAR00001415778_RNA_PAIRED_ICGC_GBM65_tumor_SN935_0209_B_C5H9HACXXs_141023_1'
#  'icgc/_EGAR00001415780_RNA_PAIRED_ICGC_GBM67_tumor_SN935_0209_B_C5H9HACXXs_141023_3'
#  'icgc/_EGAR00001415783_RNA_PAIRED_ICGC_GBM73_tumor_SN935_0209_B_C5H9HACXXs_141023_4'
#  'icgc/EGAD00001001944_ICGC_GBM1_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM11_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM16_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM17_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM18_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM19_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM2_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM5_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM6_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_GBM7_RNA-seq'
#  'icgc/EGAD00001001944_ICGC_INF_51_RNA-seq'
#  'icgc/_EGAR00001415784_RNA_PAIRED_ICGC_GBM80_tumor_SN935_0209_B_C5H9HACXXs_141023_8'
#  'TARGET-51-PAEALX' 'TARGET-51-PAJLIV' 'TARGET-51-PAJLWU'
#  'TARGET-51-PAJMFS' 'TARGET-51-PAJMNM' 'TARGET-51-PAJNCV'
#  'TARGET-51-PAJPFB' 'TARGET-51-PAKWMM' 'TARGET-51-PALEIR'
#  'TARGET-51-PALFEF' 'TARGET-51-PALFYG' 'TARGET-51-PALKEI'
#  'TARGET-51-PALLXV']
#  ```
#  ```
# Unique values in column 'study_dataset_id':
# ['7316-2140-T, aliquot 470436, cohort CPF1601003'
#  '7316-219-T, aliquot 225347.2253'
#  '7316-135-T, aliquot 116304.116311.116318'
#  '7316-1480-T, aliquot 470425, cohort CPF1601003'
#  '7316-3-T, aliquot 470422, cohort CPF1601003'
#  '7316-529-T, aliquot 470022, cohort CPF1601002'
#  '7316-659-T, aliquot 470424, cohort CPF1601003'
#  '7316-423-T, aliquot 470419, cohort CPF1601003'
#  '7316-425-T, aliquot 470441, cohort CPF1601003' nan
#  '7316-532-T, aliquot 470434, cohort CPF1601003'
#  '7316-111-T, aliquot 470423, cohort CPF1601003'
#  '7316-292-T, aliquot 470438, cohort CPF1601003'
#  '7316-334-T, aliquot 470437, cohort CPF1601003'
#  '7316-1844-T, aliquot 470026, cohort CPF1601002'
#  '7316-1893-T, aliquot 470029, cohort CPF1601002'
#  '7316-1102-T, aliquot 470031, cohort CPF1601002'
#  '7316-1105-T, aliquot 470017, cohort CPF1601002'
#  '7316-1464-T, aliquot 470021, cohort CPF1601002'
#  '7316-1723-T, aliquot 470023, cohort CPF1601002'
#  '7316-430-T, aliquot 470019, cohort CPF1601002'
#  '7316-1099-T, aliquot 470025, cohort CPF1601002'
#  '7316-714-T, aliquot 470018, cohort CPF1601002'
#  '7316-895-T, aliquot 470020, cohort CPF1601002'
#  '7316-1473-T, aliquot 470024, cohort CPF1601002'
#  '7316-1694-T, aliquot 470027, cohort CPF1601002'
#  '7316-212-T, aliquot 470016, cohort CPF1601002'
#  '7316-71-T, aliquot 470015, cohort CPF1601002'
#  '7316-736-T, aliquot 470432, cohort CPF1601003'
#  '7316-740-T, aliquot 470429, cohort CPF1601003'
#  '7316-764-T, aliquot 470427, cohort CPF1601003'
#  '7316-1799-T, aliquot 470428, cohort CPF1601003'
#  '7316-2009-T, aliquot 470439, cohort CPF1601003'
#  '7316-1214-T, aliquot 470430, cohort CPF1601003'
#  '7316-1252-T, aliquot 470433, cohort CPF1601003'
#  '7316-1279-T, aliquot 470420, cohort CPF1601003'
#  '7316-765-T, aliquot 470731, cohort CPF1601003'
#  '7316-775-T, aliquot 470421, cohort CPF1601003'
#  '7316-872-T, aliquot 470435, cohort CPF1601003'
#  '7316-1100-T, aliquot 470028, cohort CPF1601002'
#  '7316-130-T, aliquot 470440, cohort CPF1601003'
#  '7316-189-T, aliquot 470426, cohort CPF1601003'
#  '7316-762-T, aliquot 471264, cohort CPF1601003' '7316-14-T, aliquot 8711'
#  '7316-302-T, aliquot 233109' '7316-109-T, aliquot 104702.1047'
#  '7316-1460-T, aliquot 357618' '7316-178-T, aliquot 169902.251874.169909'
#  '7316-278-T, aliquot 257637'
#  '7316-968-T, aliquot 348781, batch CPF1504009'
#  '7316-1884-T, aliquot 373280, batch CPF1504009'
#  '7316-238-T, aliquot 232096, batch CPF1504009' 'Sample_102 SRR1267597'
#  'Sample_103 SRR1267598' 'Sample_105 SRR1267600' 'Sample_118 SRR1267611'
#  'Sample_128 SRR1267619' 'Sample_130 SRR1267621' 'Sample_131 SRR1267622'
#  'Sample_132 SRR1267623' 'Sample_136 SRR1267625'
#  '7316-1769-T, aliquot 470030, cohort CPF1601002' 'Sample_106 SRR1267601'
#  'Sample_107 SRR1267602' 'Sample_108 SRR1267603' 'Sample_109 SRR1267604'
#  'Sample_111 SRR1267606' 'Sample_113 SRR1267608' 'Sample_114 SRR1267609'
#  'Sample_115 SRR1267610' 'Sample_122 SRR1267613' 'Sample_124 SRR1267615'
#  'Sample_126 SRR1267617'
#  'EGAR00001124498_RNA-seq_PAIRED_ICGC_PA100_s_120626_2b'
#  'EGAR00001124499_RNA-seq_PAIRED_ICGC_PA102_s_120626_5a'
#  'EGAR00001124500_RNA-seq_PAIRED_ICGC_PA103_s_120626_3a'
#  'EGAR00001124501_RNA-seq_PAIRED_ICGC_PA105_s_120626_7c'
#  'EGAR00001124502_RNA-seq_PAIRED_ICGC_PA107_s_120705_3b'
#  'EGAR00001124503_RNA-seq_PAIRED_ICGC_PA108_s_120705_4c'
#  'EGAR00001124504_RNA-seq_PAIRED_ICGC_PA109_s_120705_5c'
#  'EGAR00001124505_RNA-seq_PAIRED_ICGC_PA110_s_120705_6a'
#  'EGAR00001124506_RNA-seq_PAIRED_ICGC_PA112_s_120705_7b'
#  'EGAR00001124507_RNA-seq_PAIRED_ICGC_PA116_s_120705_5a'
#  'EGAR00001124508_RNA-seq_PAIRED_ICGC_PA117_s_120705_4b'
#  'EGAR00001124509_RNA-seq_PAIRED_ICGC_PA11_s_120816_5a'
#  'EGAR00001124510_RNA-seq_PAIRED_ICGC_PA134_s_120816_2b'
#  'EGAR00001124511_RNA-seq_PAIRED_ICGC_PA135_s_120816_2a'
#  'EGAR00001124512_RNA-seq_PAIRED_ICGC_PA136_s_120816_2c'
#  'EGAR00001124513_RNA-seq_PAIRED_ICGC_PA138_s_120816_3b'
#  'EGAR00001124514_RNA-seq_PAIRED_ICGC_PA140_s_120816_1b'
#  'EGAR00001124516_RNA-seq_PAIRED_ICGC_PA143_s_120816_4c'
#  'EGAR00001124517_RNA-seq_PAIRED_ICGC_PA144_s_120925_1b'
#  'EGAR00001124518_RNA-seq_PAIRED_ICGC_PA145_s_120816_4a'
#  'EGAR00001124519_RNA-seq_PAIRED_ICGC_PA147_s_120816_5b'
#  'EGAR00001124520_RNA-seq_PAIRED_ICGC_PA148_s_120925_2b'
#  'EGAR00001124521_RNA-seq_PAIRED_ICGC_PA14_s_120816_5c'
#  'EGAR00001124522_RNA-seq_PAIRED_ICGC_PA150_s_120816_8a'
#  'EGAR00001124523_RNA-seq_PAIRED_ICGC_PA157_s_120925_1a'
#  'EGAR00001124524_RNA-seq_PAIRED_ICGC_PA158_s_120816_8c'
#  'EGAR00001124525_RNA-seq_PAIRED_ICGC_PA159_s_120816_3a'
#  'EGAR00001124526_RNA-seq_PAIRED_ICGC_PA162_s_120816_1c'
#  'EGAR00001124527_RNA-seq_PAIRED_ICGC_PA163_s_120925_2a'
#  'EGAR00001124528_RNA-seq_PAIRED_ICGC_PA165_s_120816_4b'
#  'EGAR00001124537_RNA-seq_PAIRED_ICGC_PA4_s_120816_4c'
#  'EGAR00001124553_RNA-seq_PAIRED_ICGC_PA82_s_120626_4b'
#  'EGAR00001124554_RNA-seq_PAIRED_ICGC_PA83_s_120626_1a'
#  'EGAR00001124561_RNA-seq_PAIRED_ICGC_PA88_s_120626_2c'
#  'EGAR00001124562_RNA-seq_PAIRED_ICGC_PA89_s_120626_4c'
#  'EGAR00001124563_RNA-seq_PAIRED_ICGC_PA8_s_120816_4b'
#  'EGAR00001124564_RNA-seq_PAIRED_ICGC_PA91_s_120626_3b'
#  'EGAR00001124565_RNA-seq_PAIRED_ICGC_PA92_s_120626_7a'
#  'EGAR00001124566_RNA-seq_PAIRED_ICGC_PA93_s_120626_6a'
#  'EGAR00001124567_RNA-seq_PAIRED_ICGC_PA94_s_120626_4a'
#  'EGAR00001124570_RNA-seq_PAIRED_ICGC_PA96_s_120626_5c'
#  'EGAR00001124573_RNA-seq_PAIRED_ICGC_PA99_s_120626_6c'
#  'EGAR00001124574_RNA-seq_PAIRED_ICGC_PA9_s_120816_5b'
#  'icgc/EGAD00001000617_ICGC_PA84_RNA-seq'
#  'icgc/EGAD00001000617_ICGC_PA87_RNA-seq'
#  'icgc/EGAD00001000617_ICGC_PA95_RNA-seq'
#  'EGAR00001415737_RNA_PAIRED_ICGC_GBM15_tumor_SN935_0182_B_C2UKHACXXs_131105_1'
#  'EGAR00001415749_RNA_PAIRED_ICGC_GBM24_tumor_SN935_0169_B_D2335ACXXs_130809_5'
#  'EGAR00001415750_RNA_PAIRED_ICGC_GBM25_tumor_SN935_0169_B_D2335ACXXs_130809_6'
#  'EGAR00001415751_RNA_PAIRED_ICGC_GBM26_tumor_SN935_0169_B_D2335ACXXs_130809_7'
#  'EGAR00001415752_RNA_PAIRED_ICGC_GBM27_tumor_SN935_0182_B_C2UKHACXXs_131105_2'
#  'EGAR00001415753_RNA_PAIRED_ICGC_GBM28_tumor_SN935_0182_B_C2UKHACXXs_131105_3'
#  'EGAR00001415754_RNA_PAIRED_ICGC_GBM32_tumor_SN935_0182_B_C2UKHACXXs_131105_5'
#  'EGAR00001415755_RNA_PAIRED_ICGC_GBM33_tumor_SN935_0182_B_C2UKHACXXs_131105_6'
#  'EGAR00001415756_RNA_PAIRED_ICGC_GBM34_tumor_SN935_0182_B_C2UKHACXXs_131105_7'
#  'EGAR00001415758_RNA_PAIRED_ICGC_GBM38_tumor_SN546_0224_B_C2U5JACXXs_131127_1'
#  'EGAR00001415759_RNA_PAIRED_ICGC_GBM39_tumor_SN546_0224_B_C2U5JACXXs_131127_2'
#  'EGAR00001415760_RNA_PAIRED_ICGC_GBM4_tumor_SN546_0221_B_C2TB7ACXXs_131022_8'
#  'EGAR00001415757_RNA_PAIRED_ICGC_GBM36_tumor_SN935_0182_B_C2UKHACXXs_131105_8'
#  'EGAR00001415763_RNA_PAIRED_ICGC_GBM49_tumor_SN546_0255_A_C5R5YACXXs_141028_6'
#  'EGAR00001415761_RNA_PAIRED_ICGC_GBM40_tumor_SN546_0224_B_C2U5JACXXs_131127_4'
#  'EGAR00001415762_RNA_PAIRED_ICGC_GBM41_tumor_SN546_0224_B_C2U5JACXXs_131127_3'
#  'EGAR00001415767_RNA_PAIRED_ICGC_GBM52_tumor_SN546_0234_A_C3G07ACXXs_140411_3'
#  'EGAR00001415768_RNA_PAIRED_ICGC_GBM53_tumor_SN546_0234_A_C3G07ACXXs_140411_4'
#  'EGAR00001415769_RNA_PAIRED_ICGC_GBM56_tumor_SN546_0255_A_C5R5YACXXs_141028_7'
#  'EGAR00001415770_RNA_PAIRED_ICGC_GBM57_tumor_SN546_0234_A_C3G07ACXXs_140411_6'
#  'EGAR00001415771_RNA_PAIRED_ICGC_GBM58_tumor_SN546_0234_A_C3G07ACXXs_140411_7'
#  'EGAR00001415772_RNA_PAIRED_ICGC_GBM59_tumor_SN546_0234_A_C3G07ACXXs_140411_8'
#  'EGAR00001415775_RNA_PAIRED_ICGC_GBM60_tumor_SN546_0235_B_C3NW7ACXXs_140411_1'
#  'EGAR00001415776_RNA_PAIRED_ICGC_GBM62_tumor_SN935_0203_B_C48T1ACXXs_140821_1'
#  'EGAR00001415777_RNA_PAIRED_ICGC_GBM63_tumor_SN546_0255_A_C5R5YACXXs_141028_8'
#  'EGAR00001415778_RNA_PAIRED_ICGC_GBM65_tumor_SN935_0209_B_C5H9HACXXs_141023_1'
#  'EGAR00001415780_RNA_PAIRED_ICGC_GBM67_tumor_SN935_0209_B_C5H9HACXXs_141023_3'
#  'EGAR00001415783_RNA_PAIRED_ICGC_GBM73_tumor_SN935_0209_B_C5H9HACXXs_141023_4'
#  'EGAD00001001944_ICGC_GBM1_RNA-seq' 'EGAD00001001944_ICGC_GBM11_RNA-seq'
#  'EGAD00001001944_ICGC_GBM16_RNA-seq' 'EGAD00001001944_ICGC_GBM17_RNA-seq'
#  'EGAD00001001944_ICGC_GBM18_RNA-seq' 'EGAD00001001944_ICGC_GBM19_RNA-seq'
#  'EGAR00001415766_RNA_PAIRED_ICGC_GBM50_tumor_SN546_0234_A_C3G07ACXXs_140411_1'
#  'EGAD00001001944_ICGC_GBM2_RNA-seq' 'EGAD00001001944_ICGC_GBM5_RNA-seq'
#  'EGAD00001001944_ICGC_GBM6_RNA-seq' 'EGAD00001001944_ICGC_GBM7_RNA-seq'
#  'EGAD00001001944_ICGC_INF_51_RNA-seq'
#  'EGAR00001415784_RNA_PAIRED_ICGC_GBM80_tumor_SN935_0209_B_C5H9HACXXs_141023_8'
#  'TARGET-51-PAEALX-01' 'TARGET-51-PAJLIV-01' 'TARGET-51-PAJLWU-01'
#  'TARGET-51-PAJMFS-01' 'TARGET-51-PAJMNM-01' 'TARGET-51-PAJNCV-01'
#  'TARGET-51-PAJPFB-01' 'TARGET-51-PAKWMM-01' 'TARGET-51-PALEIR-01'
#  'TARGET-51-PALFEF-01' 'TARGET-51-PALFYG-01' 'TARGET-51-PALKEI-01'
#  'TARGET-51-PALLXV-01']
#  ```
# ```
# Unique values in column 'study_id':
# ['THR14' 'TH01' 'TH38' 'THR12' 'THR19' 'THR21' 'TARGET']
# ```
# ```
# Unique values in column 'organism':
# ['Homo sapiens']
# ```

# %% [markdown]
# #### XY coordinates from Tumor Map

# %%
file_name_xy = input("Please insert the file name containing the XY coordinates: ")
xyCoord = pd.read_csv(file_name_xy, delimiter="\t")

# %%
xyCoord.shape #(296 ,3) same number of rows, 3 columns (sample_id, x-coordinate, y-coordinate)
coordinates = xyCoord[['x','y']].values

# %%
pip install kneed

# %%
from kneed import KneeLocator
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

def find_optimal_k(data, max_k=10):
    wcss = []

    for k in range(1, max_k+1):
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        kmeans.fit(data)
        wcss.append(kmeans.inertia_)

    # Automatically detect elbow point
    kl = KneeLocator(range(1, max_k+1), wcss, curve="convex", direction="decreasing")

    print(f"Optimal k (Elbow Point): {kl.elbow}")
    return kl.elbow

    # Plot the elbow method
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, max_k+1), wcss, marker='o', linestyle='-', color='b', label="WCSS")
    plt.axvline(kl.elbow, linestyle="--", color="red", label=f"Elbow at k={kl.elbow}")
    plt.xlabel("Number of Clusters (k)")
    plt.ylabel("Within-Cluster Sum of Squares (WCSS)")
    plt.title("Elbow Method for Optimal k")
    plt.legend()
    plt.grid(True)
    plt.show()

# Usage:
optimal_clusters = find_optimal_k(coordinates, max_k=10)

# %% [markdown]
# ##### Visualize the sklearn cluster KMeans function

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt 

def cluster(data, num_clusters, coordinatesList):
    kmeans = KMeans(n_clusters= num_clusters, random_state=42, n_init=50)
    data['cluster'] = kmeans.fit_predict(coordinatesList)
    return data 

def plot(data):
    plt.scatter(data['x'], data['y'], c = xyCoord['cluster'], cmap= 'viridis')
    plt.xlabel("x")
    plt.ylabel("y")
    # Annotate centroids with a special label
    for i, (x, y) in enumerate(centroids):
        plt.text(x, y+10, f'Cluster {i+1}', fontsize=12, ha='center', va='center', color='red', alpha=1)
    plt.title("K-means Clustering of XY coordinates using Sklearn")
    plt.show()

xyCoord = cluster(data = xyCoord, num_clusters= optimal_clusters, coordinatesList=coordinates)

plot(xyCoord)

# %% [markdown]
# ##### My own K-Means clustering implementation

# %%
import numpy as np 

def my_kmeans(X, k, max_iters=10000, tol=1e-4, random_state=42):
    """
    A simple K-means clustering implementation.

    Parameters:
    -----------
    X : numpy.ndarray, shape (n_samples, n_features)
        Your data to be clustered.
    k : int
        The number of clusters.
    max_iters : int
        Maximum number of iterations to run the K-means algorithm.
    tol : float
        Tolerance threshold for declaring convergence. If the shift of all centroids
        is below this value, we stop early.
    random_state : int
        Seed for reproducibility.

    Returns:
    --------
    labels : numpy.ndarray, shape (n_samples,)
        Cluster index for each sample.
    centroids : numpy.ndarray, shape (k, n_features)
        Final cluster centroid positions.
    """
    np.random.seed(random_state)

    # 1. Initialize centroids by randomly picking k distinct points from X
    random_indices = np.random.choice(X.shape[0], k, replace=False)
    centroids = X[random_indices, :]

    for iteration in range(max_iters):
        # 2. Assign each sample to the closest centroid
        #    - Compute distances from each sample to each centroid
        distances = np.linalg.norm(X[:, None] - centroids[None, :], axis=2)
        #    - Find the cluster index (centroid) with minimal distance
        labels = np.argmin(distances, axis=1)

        # 3. Compute new centroids based on the mean of samples in each cluster
        new_centroids = np.array([X[labels == c].mean(axis=0) for c in range(k)])

        # 4. Check how far centroids have moved
        centroid_shifts = np.linalg.norm(new_centroids - centroids, axis=1)
        if np.all(centroid_shifts < tol):
            print(f"Converged after {iteration} iterations.")
            break

        centroids = new_centroids

    return labels, np.array(centroids)
    
labels, centroids = my_kmeans(coordinates, k=optimal_clusters)

print("Cluster labels:", labels)
print("Centroids:\n", centroids)
xyCoord['Manual Clustering'] = labels
xyCoord.head()

# %% [markdown]
# ##### Visualize my implementation of k-means clustering

# %%
def plot_manual_cluster(data, centers):
    plt.scatter(data['x'], data['y'], c = data['Manual Clustering'], cmap = 'viridis')
    plt.scatter(centers[:,0], centers[:,1], c = "red", s = 12)
    # Annotate centroids with a special label
    for i, (x, y) in enumerate(centroids):
        plt.text(x, y+10, f'Cluster {i+1}', fontsize=12, ha='center', va='center', color='red', alpha=1)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Manual K-Means Clustering of XY Coordinates')
    plt.show()

plot_manual_cluster(xyCoord, centroids)

# %% [markdown]
# ##### Export the labels as a tab delimited file to add as a feature to tumormap

# %% [markdown]
# 1. Create the subset of the dataframe, this could be omitted as the sklearn implementation might be removed all together

# %%
xyCoord_Clustered = xyCoord[["#ID", "x", "y", "Manual Clustering"]]
xyCoord_Clustered.head()

# %% [markdown]
# 2. Write the dataframe to the new file, can also just overwrite original file

# %%
xyCoord_Clustered.to_csv("updated_data.tab", sep = "\t", index = False)
